# %% [markdown]
# <a href="https://colab.research.google.com/github/m-fatahillah/JOBSHEET-12Rekursif/blob/main/latihan_integrasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 20
name = "fatah"
kelas = "3f"

print(age, name, kelas);
# Out:
# 25 bujang 3f
